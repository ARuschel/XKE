# %%
import pandas as pd

# %%
see = pd.read_csv('Exploratory_phase_overalls.tsv', sep="\t")

# %%
see.transpose()
# Out:
#                                                                                0  \
# Unnamed: 0                                                                     0
# (macro) Embedding Test Accuracy                                         0.868551
# (macro) Embedding Train Accuracy                                        0.938563
# (macro) Test # Features / Example                                        189.304
# (macro) Test # Features / Example (Filter # Fea...                       317.547
# (macro) Test # Relevant Features / Example                               42.1337
# (macro) Test # Relevant Features / Example (Fil...                        81.028
# (macro) Test % Examples with # Features > 0                             0.541708
# (macro) Test % Examples with # Relevant Feature...                      0.457546
# (macro) Test Accuracy                                                   0.859152
# (macro) Test Accuracy (Filter # Features > 0)                           0.850374
# ...
