# %%
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %% [markdown]
# ## Time stamps from previous experiments:
#
# ### WHI:
#
# FB13/TransE: 1527033688
#
# NELL186/TransE: 1526711822
#
# ### WPGEC:
#
# FB13/Analogy: 1539022851
#
# NELL186/Analogy: 1526567410

# %%
col_names = ['timestamp',
             'dataset_name',
             'split', 
             'Embedding Test Accuracy', 
             'Test # Features / Example',
             'Test % Examples with # Features > 0',
             'Test # Relevant Features / Example (Filter # Relevant Features > 0)',
             'Test Mean Relevant Rule Length','Test Accuracy',
             'Test Accuracy (Filter # Features > 0)',
             'Test Accuracy (Weighted # Features)', 
             'True Test Accuracy','True Test Accuracy (Filter # Features > 0)',
             'True Test Accuracy (Weighted # Features)',
             'Test F1_score',
             'True Test F1_score']

# %%
sem = pd.read_csv('Exploratory_phase_overalls.tsv', sep="\t")
sem = sem[(sem['timestamp'] == '1552996885') |
         (sem['timestamp'] == '1526567410_sfe_ar')]
sem[col_names].sort_values(['split', 'timestamp'])
# Out:
#            timestamp dataset_name                         split  \
# 7  1526567410_sfe_ar      NELL186         g_2negrate_bern___pra
# 3         1552996885      NELL186         g_2negrate_bern___pra
# 4  1526567410_sfe_ar      NELL186  ghat_3nn_2negrate_bern___pra
# 0         1552996885      NELL186  ghat_3nn_2negrate_bern___pra
# 6  1526567410_sfe_ar      NELL186  ghat_5nn_2negrate_bern___pra
# 2         1552996885      NELL186  ghat_5nn_2negrate_bern___pra
# 5  1526567410_sfe_ar      NELL186  ghat_7nn_2negrate_bern___pra
# 1         1552996885      NELL186  ghat_7nn_2negrate_bern___pra
#
#    Embedding Test Accuracy  Test # Features / Example  \
# 7                  0.92780                  75.280200
# 3                  0.91685                  70.394437
# 4                  0.92780                 376.218300
# 0                  0.91685                 190.486992
# 6                  0.92780                 699.440500
# 2                  0.91685                 267.752151
# 5                  0.92780                1065.651400
# 1                  0.91685                 259.252151
#
#    Test % Examples with # Features > 0  \
# 7                             0.556100
# 3                             0.501601
# 4                             0.656700
# 0                             0.542225
# 6                             0.717100
# 2                             0.555834
# 5                             0.754000
# 1                             0.568041
#
#    Test # Relevant Features / Example (Filter # Relevant Features > 0)  \
# 7                                          61.257533
# 3                                          57.370865
# 4                                         203.979901
# 0                                          74.591690
# 6                                         532.519478
# 2                                         134.432520
# 5                                         825.215762
# 1                                         147.379446
#
#    Test Mean Relevant Rule Length  Test Accuracy  \
# 7                        3.729484       0.941800
# 3                        3.816914       0.896938
# 4                        3.846213       0.934900
# 0                        3.833254       0.865119
# 6                        3.897725       0.936900
# 2                        3.881060       0.846708
# 5                        3.914557       0.935900
# 1                        3.878169       0.842005
#
#    Test Accuracy (Filter # Features > 0)  Test Accuracy (Weighted # Features)  \
# 7                               0.925013                             0.971763
# 3                               0.909037                             0.972397
# 4                               0.912746                             0.963850
# 0                               0.901458                             0.951242
# 6                               0.920234                             0.948993
# 2                               0.900990                             0.944700
# 5                               0.922016                             0.949066
# 1                               0.903999                             0.930648
#
#    True Test Accuracy  True Test Accuracy (Filter # Features > 0)  \
# 7            0.941000                                    0.945334
# 3            0.904443                                    0.939757
# 4            0.927900                                    0.908939
# 0            0.863818                                    0.908655
# 6            0.930900                                    0.911728
# 2            0.847809                                    0.911431
# 5            0.936300                                    0.920027
# 1            0.843106                                    0.912278
#
#    True Test Accuracy (Weighted # Features)  Test F1_score  True Test F1_score
# 7                                  0.980157       0.929633            0.935291
# 3                                  0.975488       0.870667            0.887608
# 4                                  0.971470       0.918951            0.919476
# 0                                  0.952086       0.813645            0.822030
# 6                                  0.954008       0.923900            0.924013
# 2                                  0.958687       0.800417            0.812913
# 5                                  0.958639       0.923258            0.930705
# 1                                  0.947317       0.767701            0.782455
