# %%
import pandas as pd
import numpy as np
import os
from collections import Counter

from tools import train_test

from tqdm import tqdm_notebook as tqdm

# %load_ext autoreload
# %autoreload 2

# %%
model = 'TransE'
dataset = 'FB13'
timestamp = '1527033688'

# model = 'TransE'
# dataset = 'NELL186'
# timestamp = '1526711822'

# model = 'Analogy'
# dataset = 'NELL186'
# timestamp = '1526567410'

benchmark_dataset_path = os.path.join('~/proj', 'XKEc', 'benchmarks', dataset)
model_path = os.path.join('/home/andrey/hdd/proj/XKEc/results', dataset, model, timestamp)

model_path
# Out:
# '/home/andrey/hdd/proj/XKEc/results/FB13/TransE/1527033688'

# %%
entities = pd.read_csv(os.path.join(benchmark_dataset_path, 'entity2id.txt'), 
                       skiprows = 1, 
                       sep='\t',
                       names = ['ent', 'id'])

relations = pd.read_csv(os.path.join(benchmark_dataset_path, 'relation2id.txt'), 
                       skiprows = 1, 
                       sep='\t',
                       names = ['rel', 'id'])

valid_positive = pd.read_csv(os.path.join(benchmark_dataset_path, 'valid2id.txt'), 
                       skiprows = 1, 
                       sep=' ',
                       names = ['e1', 'e2', 'rel'])

valid_positive['label'] = 1.0

valid_negative = pd.read_csv(os.path.join(benchmark_dataset_path, 'valid2id_neg.txt'), 
                       skiprows = 1, 
                       sep=' ',
                       names = ['e1', 'e2', 'rel'])
valid_negative['label'] = 0.0


valid_set = valid_positive.append(valid_negative, ignore_index=True)

# valid_set = pd.read_csv(os.path.join(benchmark_dataset_path, 'train2id.txt'), 
#                        skiprows = 1, 
#                        sep=' ',
#                        names = ['e1', 'e2', 'rel'])

# valid_set['label'] = 1.0

valid_set.shape
# Out:
# (11816, 4)

# %%
model_info = train_test.read_model_info(model_path)
model_info
# Out:
# {'Unnamed: 0': 0,
#  'acc': 0.8254329562187195,
#  'bern': 1,
#  'cuda_device': 0,
#  'dataset_name': 'FB13',
#  'ent_neg_rate': 1,
#  'hits_10_filter': 0.3477857708930969,
#  'hits_10_raw': 0.3447309732437134,
#  'hits_1_filter': 0.19449710845947266,
#  'hits_1_raw': 0.18996754288673398,
#  'hits_3_filter': 0.2726793885231018,
#  'hits_3_raw': 0.2689293622970581,
#  'k': 100,
#  'learning_rate': 0.001,
#  'learning_time': 773.4418108463287,
#  'log_on': 1,
#  'log_print': True,
#  'log_type': 'epoch',
#  'margin': 1.0,
#  'model_name': 'TransE',
#  'mr_filter': 8762.4619140625,
#  'mr_raw': 13547.830078125,
#  'mrr_filter': 0.2488585412502289,
#  'mrr_raw': 0.2449391633272171,
#  'n_batches': 100,
#  'n_epochs': 1000,
#  'note': 'following NMM paper, no l2 constr in rel',
#  'opt_method': 'RMSProp',
#  'rel_neg_rate': 0,
#  'score_norm': 'l2',
#  'shuffle': 1,
#  'test_link_prediction': True,
#  'test_triple_class': True,
#  'testing_time': 1087.2861058712006,
#  'timestamp': '1527033688',
#  'work_threads': 8}

# %%
con = train_test.restore_model(model_path)
# Out:
# INFO:tensorflow:Restoring parameters from /home/andrey/hdd/proj/XKEc/results/FB13/TransE/1527033688/tf_model/model.vec.tf

# %%
t_set = valid_set.copy()
h = np.array(t_set['e1'])
t = np.array(t_set['e2'])
r = np.array(t_set['rel'])
l = np.array(t_set['label'])

# %%
# con.init_triple_classification()
res = con.test_step(h, t, r)

# %%
t_set['res'] = res

# %%
thresholds = con.get_thresholds_dict(r)

# %%
t_set['thres'] = t_set['rel'].map(thresholds)

# %%
t_set['pred'] = np.where(t_set['res'] < t_set['thres'], 1, 0)

# %%
t_set['label'] = t_set['label'].astype(str).str[0]
t_set['check'] = t_set['label'].astype(str) + t_set['pred'].astype(str)

# %%
count = Counter(t_set['check'])
count
# Out:
# Counter({'00': 5024, '01': 884, '10': 1157, '11': 4751})

# %%
new_acc = 100.00 * (count['00'] + count['11']) / len(t_set)

# %%
new_acc
# Out:
# 82.72681110358836

# %%
con.validation_acc()
# Out:
# 0.827268123626709

# %%
# final_test = []
# for i in range(len(pred)):
#     final_test.append(str(int(l[i])) + '_' + str(int(pred[i])))

# %%
# Counter(final_test)

# %%
t_set.head(10)
# Out:
#       e1     e2  rel label       res     thres  pred check
# 0  23041  67451    5     1  0.038460  0.032075     0    10
# 1  14257  68833    3     1  0.522386  0.547903     1    11
# 2  29865  67534    6     1  0.570176  0.580372     1    11
# 3  38636  67574    3     1  0.553331  0.547903     0    10
# 4  12548  67408    6     1  0.560282  0.580372     1    11
# 5  43602  69400    3     1  0.566670  0.547903     0    10
# 6  20362  67532    6     1  0.576972  0.580372     1    11
# 7  12860  67426    6     1  0.568382  0.580372     1    11
# 8  16190  67497    0     1  1.010737  1.059594     1    11
# 9  56126  67402    5     1  0.028022  0.032075     1    11

# %%
n_ent = len(entities)
triple = 1
head = t_set.iloc[triple, 0]
tail = t_set.iloc[triple, 1]
rel = t_set.iloc[triple, 2]

heads = [head] * n_ent
rels = [rel] * n_ent

print('Evaluating triple ({}, {}, {}). The label is {} and the prediction is {}'.format(head, 
                        rel, tail, t_set.iloc[triple, 3], t_set.iloc[triple, 6]))
# Out:
# Evaluating triple (14257, 3, 68833). The label is 1 and the prediction is 1

# %%
con.get_true_tails(head, rel, tail, thresholds[rel], k = n_ent)
# Out:
# (46, 524)

# %%
pred1 = list(con.predict_tail_entity(head, rel, k = n_ent))
con.calculate_true_triples([head]*n_ent, pred1, [rel]*n_ent)
# Out:
# array([0.4942315 , 0.4955931 , 0.49575502, ..., 0.6625423 , 0.6644705 ,
#        0.69270134], dtype=float32)

# %%
pred1.index(tail) + 1
# Out:
# 46

# %%
n_ent = len(entities)

positive_tails = []
positive_heads = []

link_prediction_tail = []
link_prediction_head = []

for i in tqdm(range(len(t_set))):
    head = h[i]
    tail = t[i]
    rel = r[i]
    rank, positives = con.get_true_tails(head, rel, tail, thresholds[rel], k=n_ent)
    link_prediction_tail.append(rank)
    positive_tails.append(positives)
    rank, positives = con.get_true_heads(tail, rel, head, thresholds[rel], k=n_ent)
    link_prediction_head.append(rank)
    positive_heads.append(positives)
# Out:
# HBox(children=(IntProgress(value=0, max=11816), HTML(value=u'')))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-17601c443744> in <module>()
#      14     link_prediction_tail.append(rank)
#      15     positive_tails.append(positives)
# ---> 16     rank, positives = con.get_true_heads(tail, rel, head, thresholds[rel], k=n_ent)
#      17     link_prediction_head.append(rank)
#      18     positive_heads.append(positives)
#
# /home/andrey/ciaamS02/proj/XKEc/config/Config.pyc in get_true_heads(self, t, r, h, threshold, k)
#     655         test_h = np.array(range(self.entTotal))
#     656         test_r = np.array([r] * self.entTotal)
# --> 657         test_t = np.array([t] * self.entTotal)
#     658         res = np.squeeze(self.test_step(test_h, test_t, test_r).reshape(-1))
#     659
#
# KeyboardInterrupt:

# %%
np.array(positive_tails).sum()
# Out:
# 814978

# %%
np.array(positive_heads).sum()
# Out:
# 358446635

# %%
pd.Series(link_prediction_head).describe()
# Out:
# count    11816.000000
# mean     30664.295785
# std      21030.874436
# min          1.000000
# 25%      11948.750000
# 50%      28203.500000
# 75%      47353.250000
# max      75037.000000
# dtype: float64

# %%
t_set['lp_tail'] = link_prediction_tail
t_set['pos_tail'] = positive_tails
t_set['lp_head'] = link_prediction_head
t_set['pos_head'] = positive_heads

# %%
t_set.head(50)
# Out:
#        e1     e2  rel label       res     thres  pred check  lp_tail  \
# 0   23041  67451    5     1  0.038460  0.032075     0    10        2
# 1   14257  68833    3     1  0.522386  0.547903     1    11       46
# 2   29865  67534    6     1  0.570176  0.580372     1    11        4
# 3   38636  67574    3     1  0.553331  0.547903     0    10       32
# 4   12548  67408    6     1  0.560282  0.580372     1    11        1
# 5   43602  69400    3     1  0.566670  0.547903     0    10      140
# 6   20362  67532    6     1  0.576972  0.580372     1    11        5
# 7   12860  67426    6     1  0.568382  0.580372     1    11        1
# 8   16190  67497    0     1  1.010737  1.059594     1    11        1
# 9   56126  67402    5     1  0.028022  0.032075     1    11        1
# 10  48131  67449    3     1  0.527656  0.547903     1    11       36
# 11  35026  67587    3     1  0.550675  0.547903     0    10       20
# 12  13897  67727    3     1  0.516700  0.547903     1    11       17
# 13  65957  67409    3     1  0.537262  0.547903     1    11       22
# 14  21553  67424    6     1  0.578209  0.580372     1    11        1
# 15  61494  67408    6     1  0.570488  0.580372     1    11        1
# 16  32783  67400    3     1  0.521733  0.547903     1    11       12
# 17  22835  67409    3     1  0.535469  0.547903     1    11       22
# 18  46341  67402    5     1  0.025582  0.032075     1    11        1
# 19  18428  67434    6     1  0.572237  0.580372     1    11        2
# 20  42119  67583    3     1  0.511479  0.547903     1    11        3
# 21  34363  67633    3     1  0.517728  0.547903     1    11       13
# 22  20740  67424    6     1  0.560035  0.580372     1    11        1
# 23  11296  67550    3     1  0.521767  0.547903     1    11       17
# 24  37964  67829    1     1  1.021188  1.048416     1    11        6
# 25  53365  67464    3     1  0.502367  0.547903     1    11        2
# 26  36875  67742    1     1  1.049909  1.048416     0    10       23
# 27   8775  67889    1     1  0.978641  1.048416     1    11        7
# 28   6072  67408    6     1  0.568573  0.580372     1    11        2
# 29   2040  67753   12     1  1.232889  1.319657     1    11        1
# 30  35192  67430    3     1  0.520779  0.547903     1    11        4
# 31  15482  67999    3     1  0.530864  0.547903     1    11       28
# 32  26214  67534    6     1  0.590229  0.580372     0    10       36
# 33  37431  67431    6     1  0.565726  0.580372     1    11        1
# 34  35323  67431    6     1  0.570844  0.580372     1    11        1
# 35  45063  67408    6     1  0.558065  0.580372     1    11        1
# 36   2737  69105    3     1  0.553392  0.547903     0    10      195
# 37  43374  67408    6     1  0.562695  0.580372     1    11        1
# 38  14208  67408    6     1  0.580433  0.580372     0    10        3
# 39  62960  67431    6     1  0.561708  0.580372     1    11        1
# 40  23071  67402    5     1  0.027349  0.032075     1    11        1
# 41  52114  67800    3     1  0.510379  0.547903     1    11       10
# 42  54514  68833    3     1  0.553293  0.547903     0    10       49
# 43  38641  67408    6     1  0.575283  0.580372     1    11        5
# 44  60892  67547    6     1  0.579812  0.580372     1    11        5
# 45  23689  67402    5     1  0.029206  0.032075     1    11        1
# 46  14236  67408    6     1  0.564909  0.580372     1    11        1
# 47  60539  67527    3     1  0.539651  0.547903     1    11       17
# 48  34803  67408    6     1  0.566740  0.580372     1    11        2
# 49  26588  67408    6     1  0.566394  0.580372     1    11        4
#
#     pos_tail  lp_head  pos_head
# 0          1    43310      1844
# 1        524       42     27644
# 2         40      315     20052
# 3         21    65801     54870
# 4         30     2124     59423
# 5         33    45905      7175
# 6          8    15908     30069
# 7         30    19152     65556
# 8          6    54719     75013
# 9          1    51480     69119
# 10       205     2172     36039
# 11        14    65356     60281
# 12       365      871     59092
# 13        47    28214     53984
# 14         5    60032     64908
# 15         5    27890     59423
# 16       119     7524     68012
# 17        49    24313     53984
# 18         1    32995     69119
# 19        21    14990     50996
# 20       103     9648     74111
# 21       138     4823     70034
# 22        16     1733     64908
# 23       159     3273     54838
# 24        12    64031     74849
# 25       109     5771     74816
# 26        21    42157     37705
# 27       142     1179     74865
# 28        51    21486     59423
# 29        53     1366     75000
# 30        40     7975     68716
# 31       118     7275     44681
# 32         1    60810     20052
# 33        22     4548     57749
# 34        10    17683     57749
# 35       192      719     59423
# 36       103    13256      4988
# 37        16     5405     59423
# 38         2    59556     59423
# 39        24      884     57749
# 40         1    46673     69119
# 41       241      673     70047
# 42        28    40501     27644
# 43        14    44466     59423
# 44         5    13802     15847
# 45         1    58482     69119
# 46        19    10389     59423
# 47        37    41742     59958
# 48        46    15548     59423
# 49        85    14531     59423

# %%
t_set.describe()
# Out:
#                  e1            e2           rel           res         thres  \
# count  11816.000000  11816.000000  11816.000000  11816.000000  11816.000000
# mean   31522.586154  68701.658768      4.616960      0.509281      0.510258
# std    19294.487694   1964.394809      2.462351      0.338664      0.340320
# min        3.000000  67393.000000      0.000000      0.019329      0.032075
# 25%    14828.250000  67431.000000      3.000000      0.449587      0.464917
# 50%    30256.000000  67583.000000      5.000000      0.553366      0.547903
# 75%    48230.250000  69324.000000      6.000000      0.584838      0.580372
# max    67389.000000  75032.000000     12.000000      1.411805      1.319657
#
#                pred       lp_tail      pos_tail       lp_head      pos_head
# count  11816.000000  11816.000000  11816.000000  11816.000000  11816.000000
# mean       0.476896    175.993653     68.972410  30664.295785  30335.700322
# std        0.499487   1723.769054    665.682339  21030.874436  29671.629028
# min        0.000000      1.000000      0.000000      1.000000      0.000000
# 25%        0.000000      2.000000      1.000000  11948.750000   1844.000000
# 50%        0.000000     14.000000     17.000000  28203.500000  13800.000000
# 75%        1.000000    107.000000     46.000000  47353.250000  64908.000000
# max        1.000000  68741.000000  41681.000000  75037.000000  75013.000000

# %%
t_set[(t_set['label'] == '0') & (t_set['rel'] == 0)].describe()
# Out:
#                  e1            e2    rel         res       thres        pred  \
# count    303.000000    303.000000  303.0  303.000000  303.000000  303.000000
# mean   29937.950495  70570.006601    0.0    1.078833    1.059594    0.158416
# std    19221.300969   2301.088923    0.0    0.023646    0.000000    0.365734
# min      370.000000  67393.000000    0.0    0.971118    1.059594    0.000000
# 25%    12337.000000  68209.500000    0.0    1.070190    1.059594    0.000000
# 50%    28425.000000  70244.000000    0.0    1.082190    1.059594    0.000000
# 75%    46198.500000  72370.000000    0.0    1.094376    1.059594    0.000000
# max    67383.000000  74790.000000    0.0    1.138990    1.059594    1.000000
#
#           lp_tail     pos_tail       lp_head      pos_head
# count  303.000000   303.000000    303.000000    303.000000
# mean    58.039604    42.653465  27263.333333   8428.722772
# std     36.339255   302.055610  21095.254000  18997.335463
# min      1.000000     2.000000     22.000000    266.000000
# 25%     27.000000     9.000000   9350.000000    863.000000
# 50%     57.000000    11.000000  20940.000000   1554.000000
# 75%     85.000000    15.000000  42804.000000   4131.000000
# max    172.000000  3727.000000  74920.000000  75013.000000

# %%
t_set.to_csv('false_positive_evaluation_FB13_TransE.csv', sep='\t', index=False)

# %%
valid_positive[']
# Out:
#          e1     e2  rel  label
# 0     23041  67451    5    1.0
# 1     14257  68833    3    1.0
# 2     29865  67534    6    1.0
# 3     38636  67574    3    1.0
# 4     12548  67408    6    1.0
# 5     43602  69400    3    1.0
# 6     20362  67532    6    1.0
# 7     12860  67426    6    1.0
# 8     16190  67497    0    1.0
# 9     56126  67402    5    1.0
# 10    48131  67449    3    1.0
# 11    35026  67587    3    1.0
# 12    13897  67727    3    1.0
# 13    65957  67409    3    1.0
# 14    21553  67424    6    1.0
# 15    61494  67408    6    1.0
# 16    32783  67400    3    1.0
# 17    22835  67409    3    1.0
# 18    46341  67402    5    1.0
# 19    18428  67434    6    1.0
# 20    42119  67583    3    1.0
# 21    34363  67633    3    1.0
# 22    20740  67424    6    1.0
# 23    11296  67550    3    1.0
# 24    37964  67829    1    1.0
# 25    53365  67464    3    1.0
# 26    36875  67742    1    1.0
# 27     8775  67889    1    1.0
# 28     6072  67408    6    1.0
# 29     2040  67753   12    1.0
# ...     ...    ...  ...    ...
# 5878  32106  68682    8    1.0
# 5879   9030  68621    1    1.0
# 5880  21786  67408    6    1.0
# 5881   8921  67943    6    1.0
# 5882  52299  67393    0    1.0
# 5883  41000  68155    1    1.0
# 5884  45989  67451    5    1.0
# 5885  13509  68402    8    1.0
# 5886    840  67408    6    1.0
# 5887  56279  67449    3    1.0
# 5888  24303  67424    6    1.0
# 5889  59505  67402    5    1.0
# 5890  10822  67409    3    1.0
# 5891  44350  67498    0    1.0
# 5892  46290  67402    5    1.0
# 5893  47406  67497    0    1.0
# 5894    960  67398    3    1.0
# 5895  23222  67402    5    1.0
# 5896  34048  67471    6    1.0
# 5897  28528  70176    0    1.0
# 5898  20893  67402    5    1.0
# 5899  21316  67464    3    1.0
# 5900  17185  71516    3    1.0
# 5901  58365  67937    6    1.0
# 5902  22087  67516    1    1.0
# 5903  55538  67409    3    1.0
# 5904   1591  67402    5    1.0
# 5905  21851  67464    3    1.0
# 5906  21365  67510    3    1.0
# 5907   1627  67402    5    1.0
#
# [5908 rows x 4 columns]
